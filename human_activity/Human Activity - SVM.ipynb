# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_train = pd.read_csv("train.csv")
df_test = pd.read_csv("test.csv")

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7352 entries, 0 to 7351
# Columns: 563 entries, tBodyAcc-mean()-X to Activity
# dtypes: float64(561), int64(2)
# memory usage: 31.6 MB

# %%
df_train.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X    ...     \
# ...

# %%
# def change_Activity(cols):
#    Activity = cols[0]
#    
#    if Activity == 'STANDING':
#        return 1
#    if Activity == 'SITTING' :
#        return 2
#    if Activity == 'LAYING':
#        return 3
#    if Activity == 'WALKING' :
#        return 4
#    if Activity == 'WALKING_DOWNSTAIRS':
#        return 5
#    if Activity == 'WALKING_UPSTAIRS' :
#        return 6

# %%
# df_train['Activity'] = df_train[['Activity']].apply(change_Activity, axis=1)
# df_test['Activity'] = df_test[['Activity']].apply(change_Activity, axis=1)

# %%
df_test.tail()
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 2942           0.310155          -0.053391          -0.099109
# 2943           0.363385          -0.039214          -0.105915
# 2944           0.349966           0.030077          -0.115788
# 2945           0.237594           0.018467          -0.096499
# 2946           0.153627          -0.018437          -0.137018
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 2942         -0.287866         -0.140589         -0.215088         -0.356083
# 2943         -0.305388          0.028148         -0.196373         -0.373540
# 2944         -0.329638         -0.042143         -0.250181         -0.388017
# 2945         -0.323114         -0.229775         -0.207574         -0.392380
# 2946         -0.330046         -0.195253         -0.164339         -0.430974
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X    ...     \
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler_train = StandardScaler()

# %%
scaler_train.fit(df_train.drop("Activity", axis=1))
scaled_features_train = scaler_train.transform(df_train.drop("Activity", axis=1))
df_feat_train = pd.DataFrame(scaled_features_train, columns=df_train.columns[:-1])

# %%
scaler_test = StandardScaler()
scaler_test.fit(df_test.drop("Activity", axis=1))
scaled_features_test = scaler_test.transform(df_test.drop("Activity", axis=1))
df_feat_test = pd.DataFrame(scaled_features_test, columns=df_test.columns[:-1])

# %%
df_feat_train.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.200642          -0.063683          -0.419628         -0.868814
# 1           0.055948           0.031486          -0.253908         -0.875426
# 2           0.073515          -0.043416          -0.076295         -0.869039
# 3           0.066696          -0.208422          -0.249712         -0.870626
# 4           0.030469           0.027587          -0.109848         -0.875188
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.939441         -0.737529         -0.859817         -0.939019
# 1         -0.923902         -0.849304         -0.868531         -0.921998
# 2         -0.907760         -0.893785         -0.863137         -0.898854
# 3         -0.940022         -0.921805         -0.864503         -0.938124
# 4         -0.934878         -0.921343         -0.867384         -0.931789
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X    ...     \
# ...

# %%
df_feat_test.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0          -0.277708          -0.210631           2.193076         -0.787267
# 1           0.198660           0.182591          -0.250264         -0.876984
# 2           0.024587          -0.318055          -0.228485         -0.921598
# 3          -0.061057          -0.573037          -0.213709         -0.923837
# 4           0.013823          -0.387881          -0.494639         -0.921679
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.833212         -0.093444         -0.808091         -0.839013
# 1         -0.929061         -0.858050         -0.897145         -0.928949
# 2         -0.934054         -0.907107         -0.916891         -0.933813
# 3         -0.940817         -0.919082         -0.919152         -0.941599
# 4         -0.929036         -0.949979         -0.916133         -0.923846
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X    ...     \
# ...

# %%
X_train = df_feat_train
y_train = df_train['Activity']

# %%
X_test = df_feat_test
y_test = df_test['Activity']

# %%
from sklearn.svm import SVC
model = SVC()
model.fit(X_train,y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
pred = model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[499  33   0   0   0   0]
#  [ 40 447   2   0   1   1]
#  [  0   0 537   0   0   0]
#  [  0   0   0 473  17   6]
#  [  0   0   0   5 393  22]
#  [  0   0   0   5   1 465]]

# %%
print(classification_report(y_test,pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.93      0.94      0.93       532
#           1       0.93      0.91      0.92       491
#           2       1.00      1.00      1.00       537
#           3       0.98      0.95      0.97       496
#           4       0.95      0.94      0.94       420
#           5       0.94      0.99      0.96       471
#
# avg / total       0.96      0.95      0.95      2947
