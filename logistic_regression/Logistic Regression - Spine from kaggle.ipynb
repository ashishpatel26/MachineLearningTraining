# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("Dataset_spine.csv")

# %%
df.head()
# Out:
#         Col1       Col2       Col3       Col4        Col5       Col6  \
# 0  63.027818  22.552586  39.609117  40.475232   98.672917  -0.254400
# 1  39.056951  10.060991  25.015378  28.995960  114.405425   4.564259
# 2  68.832021  22.218482  50.092194  46.613539  105.985135  -3.530317
# 3  69.297008  24.652878  44.311238  44.644130  101.868495  11.211523
# 4  49.712859   9.652075  28.317406  40.060784  108.168725   7.918501
#
#        Col7     Col8     Col9     Col10      Col11    Col12 Class_att  \
# 0  0.744503  12.5661  14.5386  15.30468 -28.658501  43.5123  Abnormal
# 1  0.415186  12.8874  17.5323  16.78486 -25.530607  16.1102  Abnormal
# 2  0.474889  26.8343  17.4861  16.65897 -29.031888  19.2221  Abnormal
# 3  0.369345  23.5603  12.7074  11.42447 -30.470246  18.8329  Abnormal
# 4  0.543360  35.4940  15.9546   8.87237 -16.378376  24.9171  Abnormal
#
#                                          Unnamed: 13
# 0                                                NaN
# 1                                                NaN
# 2  Prediction is done by using binary classificat...
# 3                                                NaN
# 4                                                NaN

# %%
df.describe()
# Out:
#              Col1        Col2        Col3        Col4        Col5        Col6  \
# count  310.000000  310.000000  310.000000  310.000000  310.000000  310.000000
# mean    60.496653   17.542822   51.930930   42.953831  117.920655   26.296694
# std     17.236520   10.008330   18.554064   13.423102   13.317377   37.559027
# min     26.147921   -6.554948   14.000000   13.366931   70.082575  -11.058179
# 25%     46.430294   10.667069   37.000000   33.347122  110.709196    1.603727
# 50%     58.691038   16.357689   49.562398   42.404912  118.268178   11.767934
# 75%     72.877696   22.120395   63.000000   52.695888  125.467674   41.287352
# max    129.834041   49.431864  125.742385  121.429566  163.071041  418.543082
#
#              Col7        Col8        Col9       Col10       Col11       Col12
# count  310.000000  310.000000  310.000000  310.000000  310.000000  310.000000
# mean     0.472979   21.321526   13.064511   11.933317  -14.053139   25.645981
# std      0.285787    8.639423    3.399713    2.893265   12.225582   10.450558
# min      0.003220    7.027000    7.037800    7.030600  -35.287375    7.007900
# 25%      0.224367   13.054400   10.417800    9.541140  -24.289522   17.189075
# 50%      0.475989   21.907150   12.938450   11.953835  -14.622856   24.931950
# 75%      0.704846   28.954075   15.889525   14.371810   -3.497094   33.979600
# max      0.998827   36.743900   19.324000   16.821080    6.972071   44.341200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 14 columns):
# Col1           310 non-null float64
# Col2           310 non-null float64
# Col3           310 non-null float64
# Col4           310 non-null float64
# Col5           310 non-null float64
# Col6           310 non-null float64
# Col7           310 non-null float64
# Col8           310 non-null float64
# Col9           310 non-null float64
# Col10          310 non-null float64
# Col11          310 non-null float64
# Col12          310 non-null float64
# Class_att      310 non-null object
# Unnamed: 13    14 non-null object
# dtypes: float64(12), object(2)
# memory usage: 34.0+ KB

# %%
df['Class_att'].value_counts()
# Out:
# Abnormal    210
# Normal      100
# Name: Class_att, dtype: int64

# %%
df.drop('Unnamed: 13', axis=1, inplace=True)

# %%
df.head()
# Out:
#         Col1       Col2       Col3       Col4        Col5       Col6  \
# 0  63.027818  22.552586  39.609117  40.475232   98.672917  -0.254400
# 1  39.056951  10.060991  25.015378  28.995960  114.405425   4.564259
# 2  68.832021  22.218482  50.092194  46.613539  105.985135  -3.530317
# 3  69.297008  24.652878  44.311238  44.644130  101.868495  11.211523
# 4  49.712859   9.652075  28.317406  40.060784  108.168725   7.918501
#
#        Col7     Col8     Col9     Col10      Col11    Col12 Class_att
# 0  0.744503  12.5661  14.5386  15.30468 -28.658501  43.5123  Abnormal
# 1  0.415186  12.8874  17.5323  16.78486 -25.530607  16.1102  Abnormal
# 2  0.474889  26.8343  17.4861  16.65897 -29.031888  19.2221  Abnormal
# 3  0.369345  23.5603  12.7074  11.42447 -30.470246  18.8329  Abnormal
# 4  0.543360  35.4940  15.9546   8.87237 -16.378376  24.9171  Abnormal

# %%
# get dummies for Class_att
df = pd.get_dummies(columns=['Class_att'], data=df, drop_first=True)

# %%
df.head()
# Out:
#         Col1       Col2       Col3       Col4        Col5       Col6  \
# 0  63.027818  22.552586  39.609117  40.475232   98.672917  -0.254400
# 1  39.056951  10.060991  25.015378  28.995960  114.405425   4.564259
# 2  68.832021  22.218482  50.092194  46.613539  105.985135  -3.530317
# 3  69.297008  24.652878  44.311238  44.644130  101.868495  11.211523
# 4  49.712859   9.652075  28.317406  40.060784  108.168725   7.918501
#
#        Col7     Col8     Col9     Col10      Col11    Col12  Class_att_Normal
# 0  0.744503  12.5661  14.5386  15.30468 -28.658501  43.5123                 0
# 1  0.415186  12.8874  17.5323  16.78486 -25.530607  16.1102                 0
# 2  0.474889  26.8343  17.4861  16.65897 -29.031888  19.2221                 0
# 3  0.369345  23.5603  12.7074  11.42447 -30.470246  18.8329                 0
# 4  0.543360  35.4940  15.9546   8.87237 -16.378376  24.9171                 0

# %%
# scale values
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaled_features = scaler.fit_transform(df.drop('Class_att_Normal', axis=1))

# %%
scaled_features
# Out:
# array([[ 0.14708636,  0.50136873, -0.6651769 , ...,  1.1671291 ,
#         -1.19658726,  1.71236843],
#        [-1.24586434, -0.74876898, -1.45300075, ...,  1.67955123,
#         -0.94032533, -0.91394145],
#        [ 0.4843695 ,  0.46793218, -0.09926175, ...,  1.63596949,
#         -1.22717809, -0.61568643],
#        ...,
#        [ 0.05520137,  0.51561812, -0.31097748, ..., -1.05158278,
#          1.44337397, -0.69303204],
#        [-0.88582307, -0.88565951, -0.55861259, ..., -0.75264852,
#          1.62384854,  0.77376463],
#        [-1.54892681, -1.24785954, -0.82539423, ...,  0.62174631,
#          1.29742294,  1.43371339]])

# %%
df_feat = pd.DataFrame(scaled_features, columns=df.columns[:-1])

# %%
df_feat.head()
# Out:
#        Col1      Col2      Col3      Col4      Col5      Col6      Col7  \
# 0  0.147086  0.501369 -0.665177 -0.184950 -1.447647 -0.708059  0.951630
# 1 -1.245864 -0.748769 -1.453001 -1.041521 -0.264385 -0.579556 -0.202553
# 2  0.484370  0.467932 -0.099262  0.273083 -0.897686 -0.795421  0.006694
# 3  0.511390  0.711562 -0.411339  0.126128 -1.207303 -0.402288 -0.363213
# 4 -0.626648 -0.789693 -1.274745 -0.215876 -0.733455 -0.490106  0.246670
#
#        Col8      Col9     Col10     Col11     Col12
# 0 -1.015066  0.434293  1.167129 -1.196587  1.712368
# 1 -0.977816  1.316291  1.679551 -0.940325 -0.913941
# 2  0.639127  1.302680  1.635969 -1.227178 -0.615686
# 3  0.259554 -0.105211 -0.176157 -1.345020 -0.652989
# 4  1.643094  0.851472 -1.059666 -0.190502 -0.069858

# %%
X = df_feat
y = df['Class_att_Normal']
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lm = LogisticRegression()

# %%
lm.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
pred = lm.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
print(confusion_matrix(y_test, pred))
# Out:
# [[65  9]
#  [ 5 24]]

# %%
print(classification_report(y_test, pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.93      0.88      0.90        74
#           1       0.73      0.83      0.77        29
#
# avg / total       0.87      0.86      0.87       103
